# %% [markdown]
# # Birds Dataset

# %% [markdown]
# ## Code Review

# %% [markdown]
# Code review with Chris, pointed out certain architectures used and suggested the addition of multiple flattening layers.

# %% [markdown]
# ## Model Architecture

# %% [markdown]
# ### First Model

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(100, (3, 3),strides = 1, activation='relu', input_shape=(180, 180, 1)))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.Conv2D(20, (3, 3),strides = 1, activation='relu'))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Conv2D(100, (3, 3), strides = 1, activation='relu'))
model1.add(layers.Flatten())
model1.add(layers.Flatten())
model1.add(layers.Dense(450, activation = 'softmax'))

# %% [markdown]
# Started with a typical convolutional network.
# Learning rate = 0.001, # of epochs = 5, Steps per epoch = 1000.

# %%
import joblib
Model_Train_acc = joblib.load('model_train_acc.pkl')
Model_Val_acc = joblib.load('model_val_acc.pkl')

# %%
import matplotlib.pyplot as plt
plt.plot(Model_Train_acc, label='Training Accuracy')
plt.plot(Model_Val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.legend(frameon=False)

# %%
Model_Train_Loss = joblib.load('model_train_loss.pkl')
Model_Val_Loss = joblib.load('model_val_loss.pkl')

# %%
plt.plot(Model_Train_Loss, label='Training loss')
plt.plot(Model_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# Through plotting the accuracy and the loss we are able to determine the functionality of the model. The accuracy for the training set started to surpass the validation set which indicates the model wasn't as accurate at predicting new data. With a final validation accuracy of 22% and 24% for the training accuracy. While the loss plot indicated that the model was underfitting as the epochs increased. As a result, decided to increase the covolutional layers for better feature detection and overall fitting.

# %% [markdown]
# ### Second Model

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(100, (3, 3),strides = 1, activation='relu', input_shape=(180, 180, 1)))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.Conv2D(100, (3, 3),strides = 1, activation='relu'))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Conv2D(200, (3, 3), strides = 1,activation='relu'))
model1.add(layers.Flatten())
model1.add(layers.Flatten())
model1.add(layers.Dense(450, activation = 'softmax'))

# %% [markdown]
# Learning rate = 0.001, # of epochs = 5, batch_size = 100.

# %%
Model1_Train_acc = joblib.load('model1_train_acc.pkl')
Model1_Val_acc = joblib.load('model1_val_acc.pkl')
plt.plot(Model1_Train_acc, label='Training Accuracy')
plt.plot(Model1_Val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.legend(frameon=False)

# %%
Model1_Train_Loss = joblib.load('model1_train_loss.pkl')
Model1_Val_Loss = joblib.load('model1_val_loss.pkl')
plt.plot(Model1_Train_Loss, label='Training loss')
plt.plot(Model1_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# The accuracy for the training data was 20.1% and the validation was 22%. The loss was 0.0113 and 0.0119 for the validation data. Hence, the accuracy was relatively low and the loss was too high. Otherwise, the model seems like it can potentially be successful at fitting the data, but needs better feature extraction and accuarcy in its detections.

# %% [markdown]
# ### Third Model

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(100, (3, 3),strides = 1, activation='relu', input_shape=(180, 180, 1)))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.Conv2D(200, (3, 3),strides = 1, activation='relu'))
model1.add(layers.Conv2D(200, (3, 3),strides = 1, activation='relu'))
model1.add(layers.MaxPooling2D((1, 1)))
model1.add(layers.Conv2D(200, (3, 3),strides = 1, activation='relu'))
model1.add(layers.MaxPooling2D((1, 1)))
model1.add(layers.Conv2D(200, (3, 3),strides = 1, activation='relu'))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.MaxPooling2D((2, 2)))
model1.add(layers.Conv2D(300, (3, 3), strides = 1,activation='relu'))
model1.add(layers.Flatten())
model1.add(layers.Flatten())
model1.add(layers.Dense(450, activation = 'softmax'))

# %% [markdown]
# Learning rate = 0.001, # of epochs = 5, batch_size = 10.

# %%
Model2_Train_acc = joblib.load('model2_train_acc.pkl')
Model2_Val_acc = joblib.load('model2_val_acc.pkl')
plt.plot(Model2_Train_acc, label='Training Accuracy')
plt.plot(Model2_Val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.legend(frameon=False)

# %%
Model2_Train_Loss = joblib.load('model2_train_loss.pkl')
Model2_Val_Loss = joblib.load('model2_val_loss.pkl')
plt.plot(Model2_Train_Loss, label='Training loss')
plt.plot(Model2_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# The overall performance of the model was better. The addition of the convolutional and maxpooling layers contributed to better classification of the training data, but not the validation data. With an accuracy of 38.37% for the training dataset and 14.3% for the validation dataset. As for the loss was significantly lower for the training dataset compared to the previous models with a value of 0.0087. Since the model is performing better with the training set this indicates it may be overfitting as a result some solutions can be implemented such as including a dropout function and/or a reduction in the learning parameters.

# %% [markdown]
# ### Fourth Model

# %%
model1 = models.Sequential()
model1.add(layers.Conv2D(32, (3, 3),strides = 1, activation='relu', input_shape=(180, 180, 1)))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.Conv2D(64, (3, 3),strides = 1, activation='relu', input_shape=(180, 180, 1)))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.Conv2D(100, (3, 3),strides = 1, activation='relu', input_shape=(180, 180, 1)))
model1.add(BatchNormalization())
model1.add(layers.MaxPooling2D((4, 4)))
model1.add(Dropout(0.5))

model1.add(layers.Flatten())
model.add(layers.Dense(units=32, activation='relu'))
model.add(layers.Dense(units=32, activation='relu'))
model1.add(layers.Dense(units=32, activation='relu'))

model1.add(layers.Dense(units=450, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 model1 = models.Sequential()
#       2 model1.add(layers.Conv2D(32, (3, 3),strides = 1, activation='relu', input_shape=(180, 180, 1)))
#       3 model1.add(BatchNormalization())
#
# NameError: name 'models' is not defined

# %% [markdown]
# Learning rate = 0.0001, Batch size = 10, Epoch # = 10.

# %%
Model3_Train_acc = joblib.load('model3_train_acc.pkl')
Model3_Val_acc = joblib.load('model3_val_acc.pkl')
plt.plot(Model3_Train_acc, label='Training Accuracy')
plt.plot(Model3_Val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.legend(frameon=False)

# %%
Model3_Train_Loss = joblib.load('model3_train_loss.pkl')
Model3_Val_Loss = joblib.load('model3_val_loss.pkl')
plt.plot(Model3_Train_Loss, label='Training loss')
plt.plot(Model3_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# In this model architecture we attempted to apply more addition convolutional layers for more accurate classification, adding dropout layers to eliminate overfitting and the addition of more Dense layers to reduce the input size and reduce the computational complexity. However, as seen from the visualization of the accuracy the training data's accuracy was increasing while the validation was decreasing significantly this indicates that the model was underfitting. As for the loss, it was opposite to the results of the accuracy as expected. As a result, this allows us to conclude that this model performed poorly compared to the previous architichure which may have been credited to the addition of multiple dense layers which decreased the accuracy and overall performance. This was important to learn as it allowed us to experiment with the dense layers. In order to improve the performance of the model, we worked on developing an architecture similar to attempt 3 while decreasing the number of dense layers while including the rest of the additions.

# %% [markdown]
# ### Fifth Model

# %%
Model4_Train_acc = joblib.load('model4_train_acc.pkl')
Model4_Val_acc = joblib.load('model4_val_acc.pkl')
plt.plot(Model4_Train_acc, label='Training Accuracy')
plt.plot(Model4_Val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.legend(frameon=False)

# %%
Model4_Train_Loss = joblib.load('model4_train_loss.pkl')
Model4_Val_Loss = joblib.load('model4_val_loss.pkl')
plt.plot(Model4_Train_Loss, label='Training loss')
plt.plot(Model4_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# This model architecture has performed better generally compared to previous models even with a slightly lower training accuracy 26% and a validation accuracy of 34.4%. However, the loss of both the training and validation was decreasing with every epoch. This difference between the training and validation performance might be due to the model underfitting and hence, it results in a larger margin of error.

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# The chosen model to work with is the fourth model as it performed the best overall.

# %% [markdown]
# ### First Attempt

# %% [markdown]
# Started with manipulating the zoom range, enabling horizontal and vertical flips. Data Augmentaion is important as it helps reduce overfitting and to produce a model trained on a larger veriety of data (reduces data scarcity).

# %%
Model5_Train_acc = joblib.load('model5_train_acc.pkl')
Model5_Val_acc = joblib.load('model5_val_acc.pkl')
plt.plot(Model5_Train_acc, label='Training Accuracy')
plt.plot(Model5_Val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.legend(frameon=False)

# %%
Model5_Train_Loss = joblib.load('model5_train_loss.pkl')
Model5_Val_Loss = joblib.load('model5_val_loss.pkl')
plt.plot(Model5_Train_Loss, label='Training loss')
plt.plot(Model5_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# This current data augmentation led to better performance of the model as it improved the fitting as seen by the comparison of the accuracy plot with the previous attempt. As for the loss, the validation data is still underfitting at instances and overfitting at other while the training data is performing well similar to the previous model prior to augmentation. However, the difference between the performance of the validation data after data augmentation is not as significant indicating the issue lies in the model architecture.

# %% [markdown]
# ### Second Attempt

# %% [markdown]
# Added a brightness range and enabled rescaling while editing the zoom range since all those features influence the classification of our Birds dataset.

# %%
Model6_Train_acc = joblib.load('model6_train_acc.pkl')
Model6_Val_acc = joblib.load('model6_val_acc.pkl')
plt.plot(Model6_Train_acc, label='Training Accuracy')
plt.plot(Model6_Val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy Comparison')
plt.legend(frameon=False)

# %%
Model6_Train_Loss = joblib.load('model6_train_loss.pkl')
Model6_Val_Loss = joblib.load('model6_val_loss.pkl')
plt.plot(Model6_Train_Loss, label='Training loss')
plt.plot(Model6_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# In the second attempt and the addition of other augmentation techniques there was no significant difference compared to the first attempt. The observations were almost identical to the first attempt. Overall, Data augmentation was beneficial in helping contribute to solving the underfitting problem that we were facing.

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# We utilized VGG16 architecture for transfer learning. We were able to attain a very high accuracy of 98% and a significant loss decrease as the number of epochs increased. The only limitation is that the loss of the validation is lower than the loss of the training, one of the reasons that may be causing this is the dropout only being applied to the training set and not the validation, hence the regulization loss is not accounted for.

# %%
Model7_Train_Loss = joblib.load('model7_train_loss.pkl')
Model7_Val_Loss = joblib.load('model7_val_loss.pkl')
plt.plot(Model7_Train_Loss, label='Training loss')
plt.plot(Model7_Val_Loss, label='Validation loss')
plt.title('Training and Validation loss Comparison')
plt.legend(frameon=False)

# %% [markdown]
# ## Resources:

# %% [markdown]
# https://www.mathworks.com/help/deeplearning/ref/vgg16.html;jsessionid=972ed0c91c2c41460d7db4953c16

# %% [markdown]
# https://blog.ml.cmu.edu/2020/08/31/4-overfitting/
